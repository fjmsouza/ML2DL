# %% [markdown]
# <a href="https://colab.research.google.com/github/fjmsouza/ML2DL/blob/main/dl_az_breast_cancer_cruzada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# entradas_breast.csv  saidas_breast.csv	sample_data

# %%
# import urllib.request MyUrl = "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin
# /breast-cancer-wisconsin.data" urllib.request.urlretrieve(MyUrl,"breast_cancer.csv")

import pandas as pd
import tensorflow.keras

from sklearn.model_selection import train_test_split
#import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import math

previsores = pd.read_csv('entradas_breast.csv')
print(previsores.head())
print(previsores.shape)

classe = pd.read_csv('saidas_breast.csv')
print(classe.head())
print(classe.shape)

previsores_treinamento, previsores_teste, classe_treinamento, classe_teste = train_test_split(previsores, classe, test_size=0.25)

print("eita")
classificador = Sequential()
#units = math.ceil((30+1)/2)
classificador.add(Dense(units= 16, activation= 'relu', kernel_initializer= 'random_uniform', input_dim= 30))
classificador.add(Dense(units=1, activation='sigmoid'))
classificador.compile(optimizer='adam', loss= 'binary_crossentropy', metrics= ['binary_accuracy'])
classificador.fit(previsores_treinamento, classe_treinamento, batch_size=10, epochs= 100)
# Out:
#     radius_mean   texture_mean   perimeter_mean   area_mean   smoothness_mean  \
# 0         17.99          10.38           122.80      1001.0           0.11840
# 1         20.57          17.77           132.90      1326.0           0.08474
# 2         19.69          21.25           130.00      1203.0           0.10960
# 3         11.42          20.38            77.58       386.1           0.14250
# 4         20.29          14.34           135.10      1297.0           0.10030
#
#     compactness_mean   concavity_mean  concave_points_mean   symmetry_mean  \
# 0            0.27760           0.3001              0.14710          0.2419
# 1            0.07864           0.0869              0.07017          0.1812
# 2            0.15990           0.1974              0.12790          0.2069
# 3            0.28390           0.2414              0.10520          0.2597
# 4            0.13280         198.0000              0.10430          0.1809
#
# ...

# %%
previsoes = classificador.predict(previsores_teste)
previsoes = (previsoes>0.5)
from sklearn.metrics import confusion_matrix, accuracy_score
precisao = accuracy_score(classe_teste, previsoes)
matriz = confusion_matrix(classe_teste,previsoes)
resultado = classificador.evaluate(previsores_teste,classe_teste)
# Out:
# ...
# 5/5 [==============================] - 1s 191ms/step - loss: 1.0607 - binary_accuracy: 0.8811
